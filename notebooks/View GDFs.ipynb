# %%
import geopandas as gpd

# %%
gdf = gpd.read_parquet("~/Downloads/heat_risk_analysis_Day 7_20240822.geoparquet")

# %%
gdf.head()
# Out:
#                                             geometry  raster_value  \
# 0  POLYGON ((-119.04229 49.0167, -119.04229 48.98...           1.0
# 1  POLYGON ((-117.55935 49.0167, -117.55935 48.98...           0.0
# 2  POLYGON ((-98.25825 49.0167, -98.25825 48.9867...           1.0
# 3  POLYGON ((-123.08047 49.00174, -123.08047 48.9...           1.0
# 4  POLYGON ((-118.33504 49.00174, -118.33504 48.9...           1.0
#
#    weighted_ALAND20  weighted_AWATER20  weighted_STATEFP10  weighted_GEOID10  \
# 0      8.607532e+08         16650253.0                53.0         5398844.0
# 1      1.861017e+09          6092253.0                53.0         5399114.0
# 2      1.117525e+09          9366431.0                38.0         3858249.0
# 3      1.265276e+07          1100110.0                53.0         5398281.0
# 4      1.199390e+08                0.0                53.0         5399146.0
#
#    weighted_MULTI_STATE  weighted_POP  weighted_PR_HRI  weighted_F_HRI  ...  \
# ...
